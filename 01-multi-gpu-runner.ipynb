# %%
# %%capture
# !pip install -q --no-deps accelerate

# %%
# !node --version
# Out:
# v22.16.0

# %%
########### RUN ON DUAL GPU ###########
# !accelerate launch --num_processes 2 --multi_gpu --mixed_precision fp16 --dynamo_backend no /content/01-multi-gpu-train.ipynb
